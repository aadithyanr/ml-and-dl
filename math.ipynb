# %%
import numpy as np 

incomes = np.random.normal(27000, 15000, 10000)
np.mean(incomes)
# Out:
# 27039.60917074914

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.hist(incomes, 50)
plt.show()
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# ...

# %%
np.median(incomes)
# Out:
# 26894.564558358

# %%
incomes = np.append(incomes, [50020103])

# %%
ages = np.random.randint(18, high = 90, size = 500)
ages
# Out:
# array([64, 47, 57, 46, 32, 28, 72, 50, 20, 59, 56, 88, 82, 66, 76, 79, 64,
#        55, 68, 21, 19, 23, 56, 31, 36, 21, 22, 47, 52, 71, 22, 54, 46, 77,
#        72, 63, 66, 60, 59, 67, 35, 88, 49, 27, 45, 42, 23, 77, 25, 83, 43,
#        69, 56, 63, 80, 79, 50, 86, 36, 53, 38, 60, 65, 48, 54, 49, 65, 50,
#        50, 89, 51, 41, 87, 23, 63, 25, 26, 18, 58, 77, 57, 64, 65, 31, 60,
#        36, 82, 89, 44, 32, 73, 67, 20, 38, 86, 72, 56, 58, 55, 42, 49, 53,
#        68, 25, 74, 44, 88, 42, 80, 66, 23, 65, 23, 56, 22, 40, 19, 44, 40,
#        65, 34, 21, 29, 47, 22, 27, 52, 47, 75, 23, 38, 40, 51, 75, 59, 73,
#        82, 19, 58, 38, 40, 21, 82, 43, 44, 18, 26, 79, 63, 22, 20, 65, 40,
#        34, 37, 86, 25, 23, 54, 40, 22, 51, 72, 54, 82, 37, 39, 55, 87, 80,
#        42, 52, 37, 83, 61, 30, 44, 52, 81, 51, 57, 39, 65, 74, 77, 70, 81,
#        51, 65, 61, 32, 68, 75, 83, 42, 87, 35, 32, 32, 69, 60, 74, 27, 42,
# ...

# %%
from scipy import stats
stats.mode(ages)
# Out:
# ModeResult(mode=65, count=14)

# %% [markdown]
# ## Ah, Variation and Standard Deviation Next

# %%
income = np.random.normal(100.0, 20.0, 10000)
plt.hist(income, 50)
plt.show()
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# ...

# %%
income.std()
# Out:
# 19.906612804625393

# %%
income.var()
# Out:
# 396.2732333532757

# %% [markdown]
# ## Data Distributions

# %%
values = np.random.uniform(-10.0, 10.0, 100000)
plt.hist(values, 50)
plt.show()
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# ...

# %% [markdown]
# ## gaussian

# %%
from scipy.stats import norm
import matplotlib.pyplot as plt

n = np.arange(-3,3,0.001)
plt.plot(n, norm.pdf(n))
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# ...

# %% [markdown]
# ## Percentiles and Moments

# %%
vals = np.random.normal(0,0.5,10000)
plt.hist(vals, 50)
plt.show()
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# ...

# %%
np.percentile(vals, 50)
# Out:
# 0.005780045024836911

# %% [markdown]
# ## more of matlplotlib

# %%
valu = np.arange(-3,3 , 0.001)

plt.plot(valu, norm.pdf(valu))
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# ...

# %%
plt.xkcd()
fig = plt.figure()
ax = fig.add_subplot(111)
# Out:
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# findfont: Font family 'xkcd' not found.
# findfont: Font family 'xkcd Script' not found.
# findfont: Font family 'Comic Neue' not found.
# ...

# %% [markdown]
# ## seaborn time!!!

# %%
import seaborn as sns
sns.set()
